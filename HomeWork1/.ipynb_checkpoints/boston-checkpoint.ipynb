# %% [markdown]
# ## Problem
# Đây là bài toán hồi quy tuyến tính (Regression)
#
# Đó là các trường sau:
# 1. CRIM: tỉ lệ tội phạm bình quan theo đầu người theo thị trấn
# 2. ZN: tỷ lệ đất được quy hoach cho các lô đất trên 25000 sq.ft
# 3. INDUS: tỷ lệ mẫu đất kinh doanh không bán lẻ trên mỗi thị trấn
# 4. CHAOS: Biến giả Charles River (= 1 nếu đường bao quanh sông; 0 nếu ngược lại)
# 5. NOX: nồng độ oxit nitric (phần trên 10 triệu)
# 6. RM: số lượng phòng trung bình trên một ngôi nhà
# 7. AGE: tỷ lệ các căn hộ có chủ sở hữu được xây dựng trước năm 1940
# 8. DIS: khoảng cách có trọng số đến năm trung tâm việc làm Boston
# 9. RAD: chỉ số khả năng tiếp cận các đường cao tốc hướng tâm
# 10. TAX: thuế suất tài sản toàn giá trị trên $ 10.000
# 11. PTRATIO: tỷ lệ học sinh-giáo viên theo thị trấn
# 12. B: 1000 (Bk - 0,63) ^ 2 trong đó Bk là tỷ lệ người da đen theo thị trấn
# 13. LSTAT: \% tình trạng dân số thấp
# 14. MEDV: Giá trị trung bình của những ngôi nhà có chủ sở hữu tính bằng \$ 1000
#
# ## Target
# Dự đoán giá trị trung bình của những ngôi nhà có chủ sở hữu (MEDV)

# %%
# Gọi các thư viện cần thiết với bài toán
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import plotly.graph_objs as go
import seaborn as sns
import os
#Metrics
from sklearn.metrics import make_scorer, accuracy_score,precision_score, r2_score, mean_squared_error
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score ,precision_score,recall_score,f1_score
#Model Selection
from sklearn.model_selection import KFold,train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
# Normalize
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

# %%
# Lấy đia chỉ làm việc hiện tại 
print(os.getcwd())
# Out:
# /home/namanh/AI/HomeWork1

# %%
# Tạo bảng với các cột và xem qua 10 sample
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
house_data = pd.read_csv('/home/namanh/DHBK_AI_ML_DL/Course/Day3/Coursew1/Data/housing.csv', header=None, delimiter=r"\s+", names=column_names)
house_data.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# ...

# %%
# Bắt đầu tìm hiểu về các trường dữ liệu
house_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
# Xác định xem mỗi trường có bao nhiêu dữ liệu unique
house_data.nunique()
# Out:
# CRIM       504
# ZN          26
# INDUS       76
# CHAS         2
# NOX         81
# RM         446
# AGE        356
# DIS        412
# RAD          9
# TAX         66
# PTRATIO     46
# B          357
# LSTAT      455
# MEDV       229
# dtype: int64

# %%
# Tìm hiểu về các giá trị của từng trường dữ liệu là số
house_data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# Xem số lượng dữ liệu trống (null)
null_info = pd.DataFrame({'Null count': house_data.isnull().sum(), 'Null ratio': house_data.isnull().sum()/len(house_data)*100})
null_info.drop('MEDV')
null_info.sort_values(by='Null ratio', ascending=False)
null_info
# Out:
#          Null count  Null ratio
# CRIM              0         0.0
# ZN                0         0.0
# INDUS             0         0.0
# CHAS              0         0.0
# NOX               0         0.0
# RM                0         0.0
# AGE               0         0.0
# DIS               0         0.0
# RAD               0         0.0
# TAX               0         0.0
# PTRATIO           0         0.0
# B                 0         0.0
# LSTAT             0         0.0
# MEDV              0         0.0

# %%
# Copy 1 bản nháp của data để vẽ và thay đổi dữ liệu
data1 = house_data.copy()
data1.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ## Kiểm tra trong data: trường nào là numberical, trường nào là categorical

# %%
features_numerical = house_data.select_dtypes(exclude = ['object']).drop(['MEDV'], axis = 1).copy()
features_numerical.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
features_categorical = house_data.select_dtypes(include = ['object']).copy()
features_categorical.columns
# Out:
# Index([], dtype='object')

# %% [markdown]
# Qua đó, ta thấy bộ dataset này chỉ gồm các dữ liệu dạng số

# %% [markdown]
# ## Visulization

# %% [markdown]
# ### Nhìn qua về phân phối của các dữ liệu

# %%
fig = plt.figure(figsize = (20,25))
sns.set(style = 'darkgrid')
for i in range(len(features_numerical.columns)):
    fig.add_subplot(5, 3, i+1)
    sns.distplot(features_numerical.iloc[:,i].dropna(), hist = True, color = 'b')
    plt.xlabel(features_numerical.columns[i])
plt.tight_layout()
# Out:
# /tmp/ipykernel_2917/3384077112.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(features_numerical.iloc[:,i].dropna(), hist = True, color = 'b')
# /tmp/ipykernel_2917/3384077112.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# Từ các hình trên ta thấy có các ngoại lệ ở trong bộ dataset này, dùng boxplot để thấy rõ hơn.
# Với các point dư ra chính là các ngoại lệ.

# %%
fig = plt.figure(figsize = (20,25))
sns.set(style = 'darkgrid')
for i in range(len(features_numerical.columns)):
    fig.add_subplot(5, 3, i+1)
    sns.boxplot(y = features_numerical.iloc[:,i].dropna())
plt.tight_layout()

# %% [markdown]
# ## Heatmap for correlation array (ma trận hệ số tương quan)
# Chúng ta có thể sử dụng hàm heatmap trong seaborn để vẽ ma trận hệ số tương quan giữa các trường trong bảng.
#
# Chính vì thế ta có thể dùng ma trận hệ số tương quan này để cắt bỏ bớt 1 số trường không cần thiết.

# %%
# Lấy correlation value 
plt.subplots(figsize = (10, 10))
sns.heatmap(house_data.corr(), annot = True)
plt.show()

# %%
# Lấy correlation value 
plt.subplots(figsize = (10, 10))
sns.heatmap(house_data.corr()[['MEDV']].abs().sort_values(by = "MEDV", ascending=False), annot = True)
plt.show()

# %% [markdown]
# Đúng như nãy chúng ta nhìn thấy từ đồ thị scatter LSTAT, RM, PTRATOR có hệ số tương quan khá cao với MEDV

# %% [markdown]
# ## Divide train, test with 0.8 and 0.2

# %%
X_train, X_test, y_train, y_test = train_test_split(data1.drop(["MEDV"], axis = 1), data1["MEDV"], test_size = 0.2, random_state = 2)

# %% [markdown]
# ## Algorithm

# %% [markdown]
# ### Use original dataset

# %% [markdown]
# #### Linear Regression

# %%
linear = LinearRegression()
linear.fit(X_train, y_train)

y_pred = linear.predict(X_test)

# R2_score 
print("R2_score: {}".format(r2_score(y_pred, y_test)))
# MSE 
print("Mean square error: {}".format(mean_squared_error(y_pred, y_test)))
# Out:
# R2_score: 0.7579300660483779
# Mean square error: 18.49542012244846

# %% [markdown]
# #### Random Forest

# %%
rf = RandomForestRegressor(n_estimators = 100, random_state = 0)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

# R2_score 
print("R2_score: {}".format(r2_score(y_pred, y_test)))
# MSE 
print("Mean square error: {}".format(mean_squared_error(y_pred, y_test)))
# Out:
# R2_score: 0.8688509305240666
# Mean square error: 9.555939970588232

# %% [markdown]
# ### Normalize

# %% [markdown]
# ### Original

# %%
scaler = RobustScaler()
transform = scaler.fit(data1.copy())
data2 = transform.transform(data1)
data2
# Out:
# array([[-0.06959315,  1.44      , -0.57164988, ...,  0.26190191,
#         -0.63768116,  0.35109718],
#        [-0.06375455,  0.        , -0.20294345, ...,  0.26190191,
#         -0.22188906,  0.05015674],
#        [-0.06376011,  0.        , -0.20294345, ...,  0.06667466,
#         -0.73263368,  1.69278997],
#        ...,
#        [-0.05445006,  0.        ,  0.17350891, ...,  0.26190191,
#         -0.57171414,  0.33855799],
#        [-0.04086745,  0.        ,  0.17350891, ...,  0.09641444,
#         -0.48775612,  0.10031348],
#        [-0.05816351,  0.        ,  0.17350891, ...,  0.26190191,
#         -0.34782609, -1.1661442 ]])

# %%
X_n_train, X_n_test, y_n_train, y_n_test = train_test_split(data2[:,:-1], data2[:,-1], test_size = 0.2, random_state = 2)

# %%
rf3 = RandomForestRegressor(n_estimators = 100, random_state = 0)
rf3.fit(X_n_train, y_n_train)

y_n_pred = rf3.predict(X_n_test)
y_nn_pred = rf3.predict(X_n_train)

# R2_score 
print("R2_score: {}".format(r2_score(y_n_pred, y_n_test)))
# MSE 
print("Mean square error: {}".format(mean_squared_error(y_n_pred, y_n_test)))
r2_score(y_nn_pred, y_n_train)
# Out:
# R2_score: 0.8702177359743687
# Mean square error: 0.1486046734264503
# 0.9804122751637913

# %%
linear3 = LinearRegression()
linear3.fit(X_n_train, y_n_train)

y_n_pred = linear3.predict(X_n_test)

# R2_score 
print("R2_score: {}".format(r2_score(y_n_pred, y_n_test)))
# MSE 
print("Mean square error: {}".format(mean_squared_error(y_n_pred, y_n_test)))
# Out:
# R2_score: 0.7579300660483783
# Mean square error: 0.2908056347315513
